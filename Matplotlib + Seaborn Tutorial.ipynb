# %% [markdown]
# # Matplotlib Tutorial
#
# **What are some of the most commonly used Data Visualization Libraries in Python?**
#
# - Welcome back you inquisitive, high-spirited Data Science & Engineering Club member.
# - That's an excellent question and well timed. That's actually what we're talking about today.
# - Who knew?  **¯\ \_(ツ)\_ /¯**
#
# "Matplotlib is a standard Data Visualization library that is used for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible."
#
# The link that leads to the documentation for Matplotlib is as follows: https://matplotlib.org/

# %%
#Remember the .pyplot!
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Basic plots using pyplot
#
# Matplotlib includes many useful plot types, as well as bells and whistles to customize all of them to fit your data visualization needs.
#
# https://matplotlib.org/stable/plot_types/index.html

# %% [markdown]
# ### Line Graph

# %%
y = [1,3,7,10]
x = [1,2,3,4]

plt.plot(x,y)
plt.title("X vs. Y", fontsize = 12)
plt.ylabel('Y', fontsize = 12)
plt.xlabel('X', fontsize = 12)
plt.show()

# %% [markdown]
# ### Changing Figure Size

# %%
plt.figure(figsize=(12, 6), dpi=80)
plt.plot([1, 3, 7, 10], [1, 4, 9, 16])
plt.title("X vs. Y", fontsize = 12)
plt.ylabel('Y', fontsize = 12)
plt.xlabel('X', fontsize = 12)
plt.show()
## Use shift + O to see complete ouputs on jupyter when you dont want the output to be scrollable

# %% [markdown]
# ### Scatter Plot

# %%
plt.figure(figsize=(8, 8))
x = np.random.random(100)
y = np.random.random(100)

plt.scatter(x,y, marker = "o", color = "b")
plt.title("X, Y Scatter", fontsize = 12)
plt.ylabel('Y', fontsize = 12)
plt.xlabel('X', fontsize = 12);

# %% [markdown]
# ### Bar Chart

# %%
label = [1,2,3,4]
height = [10,5,3,25]

plt.figure(figsize = (12,6))
plt.title("Bar Chart", fontsize = 12)
plt.ylabel('Y', fontsize = 12)
plt.xlabel('X', fontsize = 12)

plt.bar(label,height);

# %%
#Bar Chart with Labels
label = [1,2,3,4]
height = [10,5,3,25]

plt.figure(figsize = (12,6))
plt.title("Bar Chart with Labels", fontsize = 12)
plt.xlabel('Person', fontsize = 12)
plt.ylabel("Projected Wealth (Millions)", fontsize = 12)

#Specify labels for every x tick
plt.xticks(ticks = label,labels=["Le","Tolu", "Karan", "Sujan"])

plt.bar(label,height);

# %% [markdown]
# ### Histogram

# %%
x = np.random.normal(size = 1000)

plt.figure(figsize = (12,6))
plt.title("Histogram", fontsize = 12)
plt.xlabel('X', fontsize = 12)
plt.ylabel("Count", fontsize = 12)

plt.hist(x);

# %% [markdown]
# ### Mulitple Plots
#
# Sometimes it is useful to put multiple plots on the same plot for comparison, this is easily achieveable in matplotlib

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.figure(figsize=(8,6))
plt.plot(t, t, 'r--', label = "1")
plt.plot(t, t**2, 'bs', label = "2")
plt.plot(t, t**3, 'g^', label = "3")

plt.title("Multiple X vs. Y", fontsize = 12)
plt.ylabel('Y', fontsize = 12)
plt.xlabel('X', fontsize = 12)

plt.legend();

# %%
x = np.random.normal(size = 100)
y = np.random.normal(size = 100)

x2 = np.random.normal(size = 100) - 2
y2 = np.random.normal(size = 100) -2

plt.figure(figsize = (8,8))

plt.scatter(x,y, label = "class 1")
plt.scatter(x2,y2, label = "class 2")

plt.title("Multi Class Scatter")
plt.ylabel('Y', fontsize = 12)
plt.xlabel('X', fontsize = 12)

plt.legend();

# %% [markdown]
# ### adding in parameters and axis restrictions

# %%
plt.plot([1, 3, 7, 10], [1, 4, 9, 16], 'ro')
plt.axis([0, 13, 0, 20])
plt.show()

# %% [markdown]
# ### Mutiple plots at once

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs')
plt.plot(t, t**3, 'g^')
plt.show()

# %% [markdown]
# ### Can drop arguments if you dont want to define lines

# %%
# d makes diamonds and g- forces a green colored line
plt.plot(t, t, 'rd', t, t**2, t, t**3, 'g-')
plt.show()

# %% [markdown]
# # Subplots
#
# Somtimes it is useful to put multiple graphs on the same plot, we do this with subplots. Subplots work by making a grid of plots to us where we specify where on the grid a plot should be with a row column coordinate.
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 3)

# %%
# but they're  bit jumbled together, let's straighten that
fig, axes = plt.subplots(nrows = 3, ncols = 3)
plt.tight_layout()

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
import numpy as np
x = np.linspace(0, 5, 21)
y = x ** 2

# %%
# Basic Plot
plt.plot(x, y)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig, axes = plt.subplots(1, 2)
# tuple unpacking

for current_ax in axes:
    current_ax.plot(x, y)

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y, 'green')

plt.subplot(1, 2, 2)
plt.plot(y, x, 'purple')

# %%
fig1 = plt.figure()

axes1 = fig.add_axes([0.2, 0.2, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.3, 0.4, 0.5])

axes1.plot(x, y)

# %%
fig = plt.figure()

ax = fig.add_axes([0, 1, 2, 3])

ax.plot(x, y, color='blue', linewidth = 1, linestyle = '--', marker = '*', markersize = 10, 
        markerfacecolor = 'red', markeredgewidth = 2, markeredgecolor = 'green', alpha = 1) 

ax.set_title('Title')
ax.set_ylabel('Y Axis (Insert name here)')
ax.set_xlabel('X Axis (Insert name here)')
# alpha - transparency
# you can also make super custom colors if you grab a RGB hexcode
# some people make color coordinated plots, or color themed plots 
# https://www.webucator.com/article/python-color-constants-module/
# https://seaborn.pydata.org/tutorial/color_palettes.html
# Out:
# Text(0.5, 0, 'X Axis (Insert name here)')

# %%
fig.savefig('my_picture.png', dpi = 200)

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, x**2, label = "X-Squared")
ax.plot(x, x**3, label = "X-Cubed")

ax.set_title('Title')
ax.set_ylabel('Y Axis (Insert name here)')
ax.set_xlabel('X Axis (Insert name here)')
ax.legend()

# %% [markdown]
# ### Making a df from cereal and plotting its correlation matrix

# %%
df = pd.read_csv("cereal.csv")
pear_corr=df.corr(method='pearson')

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(pear_corr.corr(), fignum=f.number,cmap ='viridis')
plt.xticks(range(len(pear_corr.columns)),pear_corr.columns, rotation=45) 
plt.yticks(range(len(pear_corr.columns)),pear_corr.columns) 
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %%
iris = pd.read_csv("iris.data")

fig, ax = plt.subplots(figsize=(15,8))
ax = iris.boxplot()
plt.title("Multi Boxplot using pandas", loc="left")
plt.show()

# %%
groups = iris.groupby("class")
plt.figure(figsize=(12,8))
colors = {'Iris-setosa':'darkviolet', 'Iris-versicolor':'cornflowerblue', 'Iris-virginica':'orchid'}
for name, group in groups:
    plt.plot(group["sepal length"], group["sepal width"], marker="o", linestyle="", 
    label=name, ms=10, color=colors[name], alpha=.8)
    m, b = np.polyfit(group["sepal length"], group["sepal width"], 1)
    plt.plot(group["sepal length"], m*group["sepal length"]+b, linewidth=5, 
    color=colors[name], alpha=.5)
    
plt.legend()
plt.title('Iris Species classification')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
# Out:
# Text(0, 0.5, 'Sepal Width')

# %% [markdown]
# # Seaborn
#
# Seaborn is another data visualization library. Its based on matplotlib and offers a means to draw beautiful yet informative graphs.
#
# There are built in data sets which makes things convenient for us.
#
# - https://seaborn.pydata.org/tutorial/aesthetics.html
# - https://seaborn.pydata.org/generated/seaborn.heatmap.html
# - https://seaborn.pydata.org/generated/seaborn.pairplot.html
# - https://seaborn.pydata.org/examples/regression_marginals.html

# %%
import seaborn as sns

# %%
df = pd.read_csv("https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv")

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
sns.distplot(df['HP'])
# Out:
# <AxesSubplot:xlabel='HP'>

# %%
sns.distplot(df['Attack'])
# Out:
# <AxesSubplot:xlabel='Attack'>

# %%
sns.distplot(df['Attack'], bins = 25)
# Out:
# <AxesSubplot:xlabel='Attack'>

# %%
# allows us to join two different distributions
sns.jointplot(x = 'Speed', y = 'Attack', data = df)

# %%
sns.jointplot(x = 'Speed', y = 'Attack', data = df, kind = 'hex')
# darker when there are more points 
# shows a density at certain points

# %%
sns.jointplot(x = 'Speed', y = 'Attack', data = df, kind = 'reg')

# %%
sns.jointplot(x = 'Speed', y = 'Attack', data = df, kind = 'kde')
# gives us a darker component or a density where the points match up the most

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
sns.violinplot(x = 'Type 1', y = 'Attack', data = df, figsize = (150, 150))
# Out:
# <AxesSubplot:xlabel='Type 1', ylabel='Attack'>

# %%
ax = sns.violinplot(x = 'Type 1', y = 'Attack', data = df, figsize = (150, 150))
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45, ha = "right")
plt.tight_layout();

# %%
ax = sns.violinplot(x = 'Type 1', y = 'Sp. Atk', data = df, figsize = (150, 150))
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45, ha = "right")
plt.tight_layout();

# %%
flights = sns.load_dataset('flights')
flights.head()
# gotta convert this to matrix form to make it easier
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
fls = flights.pivot_table(index='month', columns = 'year', values = 'passengers')

# %%
fls
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(fls)
# so now it should be easier to see which months of which year had the most flights
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(fls, cmap = 'Spectral',linecolor = "white", linewidths = 1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(fls, cmap = 'coolwarm', linecolor = "white", linewidths = 1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.clustermap(fls)
# clusters columns and rows based on their similarity
# please note that the years on the x-axis aren't in order!
# We're showing which years had most similar flight pattern activity

# %% [markdown]
# And there are many more! Please refer to documentation to see the graphs available to you.
